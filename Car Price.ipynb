# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use("fivethirtyeight")

# %%
df_car=pd.read_csv("carprice.csv")

# %%
df_car.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df_car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df_car.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
df_car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df_car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
num_col = df_car.select_dtypes(include = np.number).columns
cat_col = df_car.select_dtypes(exclude = np.number).columns

print("Numerical Columns : ", num_col)
print("Categorical Columns : ",cat_col)
# Out:
# Numerical Columns :  Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')
# Categorical Columns :  Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
df_car['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
df_car[cat_col].head()
# Out:
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation enginetype cylindernumber fuelsystem
# 0        rwd          front       dohc           four       mpfi
# 1        rwd          front       dohc           four       mpfi
# 2        rwd          front       ohcv            six       mpfi
# 3        fwd          front        ohc           four       mpfi
# 4        4wd          front        ohc           five       mpfi

# %%
df_car[cat_col].tail()
# Out:
#              CarName fueltype aspiration doornumber carbody drivewheel  \
# 200  volvo 145e (sw)      gas        std       four   sedan        rwd
# 201      volvo 144ea      gas      turbo       four   sedan        rwd
# 202      volvo 244dl      gas        std       four   sedan        rwd
# 203        volvo 246   diesel      turbo       four   sedan        rwd
# 204      volvo 264gl      gas      turbo       four   sedan        rwd
#
#     enginelocation enginetype cylindernumber fuelsystem
# 200          front        ohc           four       mpfi
# 201          front        ohc           four       mpfi
# 202          front       ohcv            six       mpfi
# 203          front        ohc            six        idi
# 204          front        ohc           four       mpfi

# %%
sns.countplot(df_car['fueltype'])
# Out:
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fueltype', ylabel='count'>

# %%
#for columns
pd.set_option('display.max_columns',500)

# %%
df_car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %%
18	22	17450.0import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use ('fivethirtyeight')
sns.displot (df_car['enginesize'], kde=True, color='green', height=5)
# Out:
#   File "C:\Users\toshiba\AppData\Local\Temp/ipykernel_11484/2086263760.py", line 1
#     18	22	17450.0import seaborn as sns
#       	^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=[18,12])

plt.subplot(3,3,1)
plt.scatter(df_car.wheelbase, df_car.price)
plt.title("whelbase vs price")

plt.subplot(3,3,2)
plt.scatter(df_car.peakrpm, df_car.price)
plt.title("peakrpm vs price")

plt.subplot(3,3,3)
plt.scatter(df_car.carheight, df_car.price)
plt.title("carheight vs price")

plt.subplot(3,3,4)
plt.scatter(df_car.carlength, df_car.price)
plt.title("carlength vs price")

plt.subplot(3,3,5)
plt.scatter(df_car.curbweight, df_car.price)
plt.title("curbweight vs price")

plt.subplot(3,3,6)
plt.scatter(df_car.enginesize, df_car.price)
plt.title("enginesize vs price")

plt.subplot(3,3,7)
plt.scatter(df_car.boreratio, df_car.price)
plt.title("boreratio vs price")


plt.subplot(3,3,8)
plt.scatter(df_car.highwaympg, df_car.price)
plt.title("highwaympg vs price")



plt.show()

# %%
plt.figure(figsize=[18,12])
num_col = ['wheelbase','peakrpm','carheight','compressionratio','stroke','boreratio','enginesize','boreratio','horsepower']

for i,j in enumerate(cat_col):
    plt.subplot(3,4,i+1)
    sns.countplot(df_car[j])
    plt.title(j)
# Out:
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=[18,12])
num_col = ['wheelbase','peakrpm','carheight','compressionratio','stroke','boreratio','enginesize','boreratio','horsepower']

for i,j in enumerate(cat_col):
    plt.subplot(4,3,i+1)
    sns.countplot(df_car[j])
    plt.title(j)
# Out:
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df_car['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
df_car['CarName'] = df_car['CarName'].str.lower()
df_car['carCompany'] = df_car['CarName'].str.split(' ').str[0]
df_car = df_car.drop('CarName',axis=1)

# %%
df_car.head()
# Out:
#    car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1          3      gas        std        two  convertible        rwd
# 1       2          3      gas        std        two  convertible        rwd
# 2       3          1      gas        std        two    hatchback        rwd
# 3       4          2      gas        std       four        sedan        fwd
# 4       5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
# 1          front       88.6      168.8      64.1       48.8        2548
# 2          front       94.5      171.2      65.5       52.4        2823
# 3          front       99.8      176.6      66.2       54.3        2337
# 4          front       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# ...

# %%
df_car['carCompany'] = df_car['carCompany'].str.replace('vok','volk')
df_car['carCompany'] = df_car['carCompany'].str.replace('ou','o')
df_car['carCompany'] = df_car['carCompany'].str.replace('cshce','sche')
df_car['carCompany'] = df_car['carCompany'].str.replace('vw','volkswagen')
df_car['carCompany'] = df_car['carCompany'].str.replace('xd','zd')

# %%
#visualising categorical data


plt.figure(figsize = (25,15))

plt.subplot(3,3,1)
sns.boxplot(x = 'fueltype',y='price', data= df_raw)

plt.subplot(3,3,1)
sns.boxplot(x = '',y='price', data= df_raw)

# %%
plt.figure(figsize=[18,12])
cat_col_updated = ['wheelbase','peakrpm','carheight','compressionratio','stroke','boreratio','enginesize','boreratio','horsepower']

for i,j in enumerate(cat_col_updated):
    plt.subplot(4,3,i+1)
    sns.boxplot(df_car[j],df_car.price)
    plt.title(j)
# Out:
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\toshiba\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
le = LabelEncoder()
for i in list:
    df_car[i] = le.fit_transform(i)

# %%
df_car.head()
# Out:
#    car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1          3      gas        std        two  convertible        rwd
# 1       2          3      gas        std        two  convertible        rwd
# 2       3          1      gas        std        two    hatchback        rwd
# 3       4          2      gas        std       four        sedan        fwd
# 4       5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
# 1          front       88.6      168.8      64.1       48.8        2548
# 2          front       94.5      171.2      65.5       52.4        2823
# 3          front       99.8      176.6      66.2       54.3        2337
# 4          front       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# ...

# %%
#Label Encoder
cat_col_updated = ['carCompany','fueltype', 'aspiration', 'doornumber', 'carbody',
       'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
       'fuelsystem']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in cat_col_updated:
    df_car[i]=le.fit_transform(df_car[i])

# %%
#converting price to thousand i.e. 12.1k
df_car['price'] = df_car['price'].apply(lambda val: round(val/1000,3))
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   fueltype          205 non-null    int64
#  3   aspiration        205 non-null    int64
#  4   doornumber        205 non-null    int64
#  5   carbody           205 non-null    int64
#  6   drivewheel        205 non-null    int64
#  7   enginelocation    205 non-null    int64
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    int64
#  14  cylindernumber    205 non-null    int64
#  15  enginesize        205 non-null    int64
# ...

# %%
df_car.head()
# Out:
#    car_ID  symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0       1          3         1           0           1        0           2
# 1       2          3         1           0           1        0           2
# 2       3          1         1           0           1        2           2
# 3       4          2         1           0           0        3           1
# 4       5          2         1           0           0        3           0
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0               0      88.60     168.80     64.10      48.80        2548
# 1               0      88.60     168.80     64.10      48.80        2548
# 2               0      94.50     171.20     65.50      52.40        2823
# 3               0      99.80     176.60     66.20      54.30        2337
# 4               0      99.40     176.60     66.40      54.30        2824
#
# ...

# %%
x = df_car.drop(["price"],axis=1)
y=df_car["price"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
#linear regression

from sklearn.linear_model import LinearRegression

lr_reg = LinearRegression()

lr_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#R2 score on train set
lr_reg.score(x_train,y_train)
# Out:
# 0.9182236424491499

# %%
#R2 score on test set
lr_reg.score(x_test,y_test)
# Out:
# 0.8651380489753734

# %%
#prediction

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,lr_reg.predict(x_test))
# Out:
# 9.401639190875746e-06

# %%
error = y_test - lr_reg.predict(x_test)
sns.displot(error, kde=True)
